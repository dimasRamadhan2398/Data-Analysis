# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import yfinance as yf
import datetime as dt
from pandas import Series, DataFrame
# %matplotlib inline

# %%
stock_symbols = ["BBRI.JK", "EMTK.JK", "HRUM.JK","ASSA.JK"]
end_date = dt.datetime.today()
start_date = dt.datetime(end_date.year - 5, end_date.month, end_date.day)

# %%
df_stock = yf.download(stock_symbols, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df_stock.head()
# Out:
#            Adj Close                                        Close
#              ASSA.JK      BBRI.JK     EMTK.JK     HRUM.JK ASSA.JK BBRI.JK
# Date
# 2018-08-10     262.0  2809.611816  886.302429  493.545654   262.0  3390.0  \
# 2018-08-13     262.0  2602.412842  886.302429  458.685577   262.0  3140.0
# 2018-08-14     262.0  2594.125000  886.302429  466.024506   262.0  3130.0
# 2018-08-15     260.0  2660.428467  886.302429  473.363525   260.0  3210.0
# 2018-08-16     260.0  2527.821289  886.302429  456.850861   260.0  3050.0
#
#                               High          ...     Low            Open
#            EMTK.JK HRUM.JK ASSA.JK BBRI.JK  ... EMTK.JK HRUM.JK ASSA.JK
# Date                                        ...
# 2018-08-10   895.0   538.0   262.0  3470.0  ...   895.0   534.0   260.0  \
# 2018-08-13   895.0   500.0   264.0  3320.0  ...   895.0   500.0   262.0
# 2018-08-14   895.0   508.0   264.0  3150.0  ...   895.0   492.0   264.0
# 2018-08-15   895.0   516.0   264.0  3220.0  ...   895.0   496.0   262.0
# 2018-08-16   895.0   498.0   264.0  3180.0  ...   895.0   496.0   264.0
#
#                                        Volume
#            BBRI.JK EMTK.JK HRUM.JK    ASSA.JK      BBRI.JK EMTK.JK   HRUM.JK
# Date
# 2018-08-10  3350.0   895.0   534.0   617100.0  115961500.0    5000  11899000
# 2018-08-13  3300.0   895.0   538.0  1361200.0  179328600.0    5000  12749500
# 2018-08-14  3090.0   895.0   500.0   824200.0  154831700.0    5000  10271000
# 2018-08-15  3150.0   895.0   512.0  1645500.0  138367300.0    5000   9440500
# 2018-08-16  3180.0   895.0   518.0   822200.0  163665300.0    5000  14795000
#
# [5 rows x 24 columns]

# %%
df_stock.tail()
# Out:
#            Adj Close                           Close
#              ASSA.JK BBRI.JK EMTK.JK HRUM.JK ASSA.JK BBRI.JK EMTK.JK HRUM.JK
# Date
# 2023-08-04    1125.0  5575.0   615.0  1605.0  1125.0  5575.0   615.0  1605.0  \
# 2023-08-07    1130.0  5700.0   625.0  1630.0  1130.0  5700.0   625.0  1630.0
# 2023-08-08    1145.0  5625.0   620.0  1640.0  1145.0  5625.0   620.0  1640.0
# 2023-08-09    1120.0  5700.0   625.0  1620.0  1120.0  5700.0   625.0  1620.0
# 2023-08-10    1125.0  5700.0   635.0  1635.0  1125.0  5700.0   635.0  1635.0
#
#               High          ...     Low            Open
#            ASSA.JK BBRI.JK  ... EMTK.JK HRUM.JK ASSA.JK BBRI.JK EMTK.JK
# Date                        ...
# 2023-08-04  1155.0  5725.0  ...   610.0  1600.0  1155.0  5700.0   635.0  \
# 2023-08-07  1145.0  5725.0  ...   615.0  1605.0  1125.0  5600.0   620.0
# 2023-08-08  1165.0  5750.0  ...   620.0  1630.0  1130.0  5700.0   625.0
# 2023-08-09  1160.0  5725.0  ...   615.0  1620.0  1150.0  5650.0   615.0
# 2023-08-10  1150.0  5725.0  ...   620.0  1610.0  1120.0  5675.0   625.0
#
#                        Volume
#            HRUM.JK    ASSA.JK      BBRI.JK   EMTK.JK   HRUM.JK
# Date
# 2023-08-04  1640.0  6441800.0  150738500.0  17529400  19118900
# 2023-08-07  1605.0  4244600.0   88104900.0   9565300  11626200
# 2023-08-08  1645.0  6298500.0   89189600.0   7678900   7901500
# 2023-08-09  1650.0  5450700.0   91930000.0  13326900   6810700
# 2023-08-10  1625.0  5383000.0   85574500.0  17166200   9454000
#
# [5 rows x 24 columns]

# %%
df_stock.describe()
# Out:
#          Adj Close                                               Close
#            ASSA.JK      BBRI.JK      EMTK.JK      HRUM.JK      ASSA.JK
# count  1236.000000  1236.000000  1237.000000  1237.000000  1236.000000  \
# mean   1239.817608  3712.316140  1231.139239   924.961429  1239.817608
# std     923.983690   728.862381   678.039779   683.195179   923.983690
# min     260.000000  1922.021973   403.044830   203.742157   260.000000
# 25%     570.000000  3232.024719   713.003113   262.223694   570.000000
# 50%     825.000000  3720.719482   876.399658   841.379700   825.000000
# 75%    1758.750000  4136.333496  1856.778931  1570.000000  1758.750000
# max    3970.000000  5700.000000  2970.846436  2675.518066  3970.000000
#
#                                                      High               ...
#            BBRI.JK      EMTK.JK      HRUM.JK      ASSA.JK      BBRI.JK  ...
# count  1236.000000  1237.000000  1237.000000  1236.000000  1236.000000  ...  \
# mean   4126.890135  1242.574373   965.172191  1275.654186  4175.010534  ...
# std     645.495127   684.842565   706.088562   952.008276   640.328244  ...
# min    2170.000000   407.000000   216.000000   260.000000  2270.000000  ...
# 25%    3780.000000   717.500000   281.000000   585.000000  3827.500000  ...
# 50%    4210.000000   885.000000   892.000000   845.000000  4255.000000  ...
# 75%    4530.000000  1875.000000  1610.000000  1811.250000  4580.000000  ...
# max    5700.000000  3000.000000  2815.000000  4000.000000  5750.000000  ...
#
#                Low                      Open
#            EMTK.JK      HRUM.JK      ASSA.JK      BBRI.JK      EMTK.JK
# count  1237.000000  1237.000000  1236.000000  1236.000000  1237.000000  \
# mean   1219.179062   945.123686  1241.429170  4131.394033  1243.624899
# std     666.813004   689.795473   925.780903   644.130610   688.229717
# min     397.000000   213.000000   260.000000  2250.000000   397.000000
# 25%     710.000000   278.000000   570.000000  3787.500000   720.000000
# 50%     885.000000   844.000000   825.000000  4215.000000   885.000000
# 75%    1840.000000  1585.000000  1756.250000  4530.000000  1885.000000
# max    2960.000000  2735.000000  3900.000000  5700.000000  3040.000000
#
#                           Volume
#            HRUM.JK       ASSA.JK       BBRI.JK       EMTK.JK       HRUM.JK
# count  1237.000000  1.236000e+03  1.236000e+03  1.237000e+03  1.237000e+03
# mean    967.498787  1.236940e+07  1.486530e+08  2.188249e+07  3.267581e+07
# std     709.201925  1.349578e+07  9.509674e+07  4.058869e+07  3.951983e+07
# min     216.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     282.000000  4.411725e+06  9.057635e+07  1.200000e+04  6.810700e+06
# 50%     894.000000  8.738000e+06  1.247926e+08  9.508000e+06  1.620100e+07
# 75%    1615.000000  1.519345e+07  1.779023e+08  3.085240e+07  4.466350e+07
# max    2860.000000  1.001435e+08  8.984537e+08  9.250834e+08  3.190125e+08
#
# [8 rows x 24 columns]

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1237 entries, 2018-08-10 to 2023-08-10
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, ASSA.JK)  1236 non-null   float64
#  1   (Adj Close, BBRI.JK)  1236 non-null   float64
#  2   (Adj Close, EMTK.JK)  1237 non-null   float64
#  3   (Adj Close, HRUM.JK)  1237 non-null   float64
#  4   (Close, ASSA.JK)      1236 non-null   float64
#  5   (Close, BBRI.JK)      1236 non-null   float64
#  6   (Close, EMTK.JK)      1237 non-null   float64
#  7   (Close, HRUM.JK)      1237 non-null   float64
#  8   (High, ASSA.JK)       1236 non-null   float64
#  9   (High, BBRI.JK)       1236 non-null   float64
#  10  (High, EMTK.JK)       1237 non-null   float64
#  11  (High, HRUM.JK)       1237 non-null   float64
#  12  (Low, ASSA.JK)        1236 non-null   float64
#  13  (Low, BBRI.JK)        1236 non-null   float64
#  14  (Low, EMTK.JK)        1237 non-null   float64
#  15  (Low, HRUM.JK)        1237 non-null   float64
#  16  (Open, ASSA.JK)       1236 non-null   float64
#  17  (Open, BBRI.JK)       1236 non-null   float64
#  18  (Open, EMTK.JK)       1237 non-null   float64
#  19  (Open, HRUM.JK)       1237 non-null   float64
#  20  (Volume, ASSA.JK)     1236 non-null   float64
#  21  (Volume, BBRI.JK)     1236 non-null   float64
#  22  (Volume, EMTK.JK)     1237 non-null   int64
#  23  (Volume, HRUM.JK)     1237 non-null   int64
# dtypes: float64(22), int64(2)
# memory usage: 241.6 KB

# %%
df_assa = yf.download('ASSA.JK', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_assa.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2018-08-10  260.0  262.0  256.0  262.0      262.0   617100
# 2018-08-13  262.0  264.0  256.0  262.0      262.0  1361200
# 2018-08-14  264.0  264.0  260.0  262.0      262.0   824200
# 2018-08-15  262.0  264.0  256.0  260.0      260.0  1645500
# 2018-08-16  264.0  264.0  258.0  260.0      260.0   822200

# %%
df_assa['Close'].plot(legend=True,figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_assa['Volume'].plot(legend=True,figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
ma_days = [50,100,200]

for ma in ma_days:
    column_names = "MA for %s days" %(str(ma))
    df_assa[column_names] = df_assa['Close'].rolling(ma).mean()

# %%
df_assa[['Close','MA for 50 days','MA for 100 days','MA for 200 days']].plot(figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_assa.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume  MA for 50 days
# Date
# 2018-08-10  260.0  262.0  256.0  262.0      262.0   617100             NaN  \
# 2018-08-13  262.0  264.0  256.0  262.0      262.0  1361200             NaN
# 2018-08-14  264.0  264.0  260.0  262.0      262.0   824200             NaN
# 2018-08-15  262.0  264.0  256.0  260.0      260.0  1645500             NaN
# 2018-08-16  264.0  264.0  258.0  260.0      260.0   822200             NaN
#
#             MA for 100 days  MA for 200 days
# Date
# 2018-08-10              NaN              NaN
# 2018-08-13              NaN              NaN
# 2018-08-14              NaN              NaN
# 2018-08-15              NaN              NaN
# 2018-08-16              NaN              NaN

# %%
df_assa['Daily Return'] = df_assa['Close'].pct_change()
df_assa.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume  MA for 50 days
# Date
# 2018-08-10  260.0  262.0  256.0  262.0      262.0   617100             NaN  \
# 2018-08-13  262.0  264.0  256.0  262.0      262.0  1361200             NaN
# 2018-08-14  264.0  264.0  260.0  262.0      262.0   824200             NaN
# 2018-08-15  262.0  264.0  256.0  260.0      260.0  1645500             NaN
# 2018-08-16  264.0  264.0  258.0  260.0      260.0   822200             NaN
#
#             MA for 100 days  MA for 200 days  Daily Return
# Date
# 2018-08-10              NaN              NaN           NaN
# 2018-08-13              NaN              NaN      0.000000
# 2018-08-14              NaN              NaN      0.000000
# 2018-08-15              NaN              NaN     -0.007634
# 2018-08-16              NaN              NaN      0.000000

# %%
df_assa['Daily Return'].dropna().plot(legend=True,figsize=(16,6),marker='o',linestyle='--')
# Out:
# <Axes: xlabel='Date'>

# %%
sns.histplot(data=df_assa['Daily Return'].dropna(),kde=True,color='purple',bins=50)
# Out:
# <Axes: xlabel='Daily Return', ylabel='Count'>

# %%
df_stock['Close'].head()
# Out:
#             ASSA.JK  BBRI.JK  EMTK.JK  HRUM.JK
# Date
# 2018-08-10    262.0   3390.0    895.0    538.0
# 2018-08-13    262.0   3140.0    895.0    500.0
# 2018-08-14    262.0   3130.0    895.0    508.0
# 2018-08-15    260.0   3210.0    895.0    516.0
# 2018-08-16    260.0   3050.0    895.0    498.0

# %%
df_stock_close = df_stock['Close']
df_stock_close.head()
# Out:
#             ASSA.JK  BBRI.JK  EMTK.JK  HRUM.JK
# Date
# 2018-08-10    262.0   3390.0    895.0    538.0
# 2018-08-13    262.0   3140.0    895.0    500.0
# 2018-08-14    262.0   3130.0    895.0    508.0
# 2018-08-15    260.0   3210.0    895.0    516.0
# 2018-08-16    260.0   3050.0    895.0    498.0

# %%
pect_change = df_stock_close.pct_change()
pect_change
# Out:
#              ASSA.JK   BBRI.JK   EMTK.JK   HRUM.JK
# Date
# 2018-08-10       NaN       NaN       NaN       NaN
# 2018-08-13  0.000000 -0.073746  0.000000 -0.070632
# 2018-08-14  0.000000 -0.003185  0.000000  0.016000
# 2018-08-15 -0.007634  0.025559  0.000000  0.015748
# 2018-08-16  0.000000 -0.049844  0.000000 -0.034884
# ...              ...       ...       ...       ...
# 2023-08-04 -0.013158 -0.021930 -0.031496 -0.021341
# 2023-08-07  0.004444  0.022422  0.016260  0.015576
# 2023-08-08  0.013274 -0.013158 -0.008000  0.006135
# 2023-08-09 -0.021834  0.013333  0.008065 -0.012195
# 2023-08-10  0.004464  0.000000  0.016000  0.009259
#
# [1237 rows x 4 columns]

# %%
pect_change.dropna().plot(subplots=True,legend=True,figsize=(16,10))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
sns.jointplot(data=df_stock_close,x='ASSA.JK',y='ASSA.JK', kind='scatter',color='green')

# %%
sns.jointplot(data=df_stock_close,x='HRUM.JK',y='ASSA.JK',kind='scatter',color='seagreen')

# %%
sns.jointplot(data=df_stock_close,x='ASSA.JK',y='HRUM.JK',kind='scatter',color='red')

# %%
sns.pairplot(df_stock_close.dropna())

# %%
return_fig = sns.PairGrid(df_stock_close.dropna())
return_fig.map_upper(plt.scatter,color='green')
return_fig.map_lower(sns.kdeplot,cmap='cool_d')
return_fig.map_diag(plt.hist,bins=50)

# %%
return_fig = sns.PairGrid(pect_change.dropna())
return_fig.map_upper(plt.scatter,color='green')
return_fig.map_lower(sns.kdeplot,cmap='cool_d')
return_fig.map_diag(plt.hist,bins=50)

# %%
sns.heatmap(pect_change.corr(),annot=True)
# Out:
# <Axes: >

# %%
pect = pect_change.dropna()

area = np.pi*30

plt.scatter(pect.mean(), pect.std(),alpha=0.5,s=area)

plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label,x,y in zip(pect.columns, pect.mean(), pect.std()):
    plt.annotate(label, xy = (x,y), xytext=(50,50), textcoords='offset points', ha='right', va='bottom', 
                arrowprops = dict(arrowstyle='-', connectionstyle='arc3,rad=-0.3'))

# %%
pect['EMTK.JK'].quantile(0.01)
# Out:
# -0.06992301179435682

# %%
pect['BBRI.JK'].quantile(0.01)
# Out:
# -0.06486328920428233

# %%
pect['HRUM.JK'].quantile(0.01)
# Out:
# -0.06829723011363638

# %%
pect['ASSA.JK'].quantile(0.01)
# Out:
# -0.06840530814215023

# %%
days = 365
dt = 1/days
mu = pect.mean()['ASSA.JK']
sigma = pect.std()['ASSA.JK']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    price = np.zeros(days)
    price[0] = start_price
    drift = np.zeros(days)
    shock = np.zeros(days)
    
    for x in range(1,days):
        drift[x] = mu * dt
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma * np.sqrt(dt))
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    return price

# %%
start_price = 700

for x in range(1000):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Method for ASSA')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Method for ASSA')

# %%
runs = 10000

simulations = np.zeros(runs)

for x in range(runs):
    simulations[x] = stock_monte_carlo(start_price,days,mu,sigma)[days - 1]

# %%
q = np.percentile(simulations,1)

plt.hist(simulations,bins=200)

plt.figtext(0.6,0.8,s="Start Price: Rp.%.2f" %start_price)
plt.figtext(0.6,0.7,s="Mean Final Price: Rp.%.2f" %simulations.mean())
plt.figtext(0.6,0.6,s="VaR (0.99): Rp.%.2f" %(start_price - q))
plt.figtext(0.15,0.6,s="q(0.99): Rp.%.2f" %q)
plt.axvline(x=q,linewidth=4,color='r')
plt.title("Final price distribution for ASSA Stock after %s days" %days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for ASSA Stock after 365 days')

# %%
df_assa.tail()
# Out:
#               Open    High     Low   Close  Adj Close   Volume
# Date
# 2023-08-04  1155.0  1155.0  1110.0  1125.0     1125.0  6441800  \
# 2023-08-07  1125.0  1145.0  1110.0  1130.0     1130.0  4244600
# 2023-08-08  1130.0  1165.0  1130.0  1145.0     1145.0  6298500
# 2023-08-09  1150.0  1160.0  1120.0  1120.0     1120.0  5450700
# 2023-08-10  1120.0  1150.0  1115.0  1125.0     1125.0  5383000
#
#             MA for 50 days  MA for 100 days  MA for 200 days  Daily Return
# Date
# 2023-08-04          1241.9          1061.50          988.975     -0.013158
# 2023-08-07          1241.5          1063.05          987.950      0.004444
# 2023-08-08          1241.6          1064.80          987.075      0.013274
# 2023-08-09          1240.5          1065.85          986.175     -0.021834
# 2023-08-10          1240.1          1067.20          985.475      0.004464

# %%
mu_hrum = pect.mean()['HRUM.JK']
sigma_hrum = pect.std()['HRUM.JK']

# %%
def stock_monte_carlo_hrum(start_price_hrum,days,mu_hrum,sigma_hrum):
    price = np.zeros(days)
    price[0] = start_price_hrum
    drift = np.zeros(days)
    shock = np.zeros(days)
    
    for x in range(1,days):
        drift[x] = mu_hrum * dt
        shock[x] = np.random.normal(loc=mu_hrum*dt, scale=sigma_hrum * np.sqrt(dt))
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    return price

# %%
start_price_hrum = 2070

for x in range(1000):
    plt.plot(stock_monte_carlo_hrum(start_price_hrum,days,mu_hrum,sigma_hrum))
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Method for HRUM')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Method for HRUM')

# %%
simulations_hrum = np.zeros(runs)

for x in range(runs):
    simulations_hrum[x] = stock_monte_carlo_hrum(start_price_hrum,days,mu_hrum,sigma_hrum)[days - 1]

# %%
q_hrum = np.percentile(simulations_hrum,0.01)

plt.hist(simulations_hrum,bins=100)

plt.figtext(0.6,0.8,s="Start Price: Rp.%.2f" %start_price_hrum)
plt.figtext(0.6,0.7,s="Mean Final Price: Rp.%.2f" %simulations_hrum.mean())
plt.figtext(0.6,0.6,s="VaR (0.99): Rp.%.2f" %(start_price_hrum - q_hrum))
plt.figtext(0.15,0.6,s="q(0.99): Rp.%.2f" %q_hrum)
plt.axvline(x=q_hrum,linewidth=4,color='r')
plt.title("Final price distribution for HRUM Stock after %s days" %days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for HRUM Stock after 365 days')

# %%
df_stock
# Out:
#            Adj Close                                         Close
#              ASSA.JK      BBRI.JK     EMTK.JK      HRUM.JK ASSA.JK BBRI.JK
# Date
# 2018-08-10     262.0  2809.611816  886.302429   493.545654   262.0  3390.0  \
# 2018-08-13     262.0  2602.412842  886.302429   458.685577   262.0  3140.0
# 2018-08-14     262.0  2594.125000  886.302429   466.024506   262.0  3130.0
# 2018-08-15     260.0  2660.428467  886.302429   473.363525   260.0  3210.0
# 2018-08-16     260.0  2527.821289  886.302429   456.850861   260.0  3050.0
# ...              ...          ...         ...          ...     ...     ...
# 2023-08-04    1125.0  5575.000000  615.000000  1605.000000  1125.0  5575.0
# 2023-08-07    1130.0  5700.000000  625.000000  1630.000000  1130.0  5700.0
# 2023-08-08    1145.0  5625.000000  620.000000  1640.000000  1145.0  5625.0
# 2023-08-09    1120.0  5700.000000  625.000000  1620.000000  1120.0  5700.0
# 2023-08-10    1125.0  5700.000000  635.000000  1635.000000  1125.0  5700.0
#
#                               High          ...     Low            Open
#            EMTK.JK HRUM.JK ASSA.JK BBRI.JK  ... EMTK.JK HRUM.JK ASSA.JK
# Date                                        ...
# 2018-08-10   895.0   538.0   262.0  3470.0  ...   895.0   534.0   260.0  \
# 2018-08-13   895.0   500.0   264.0  3320.0  ...   895.0   500.0   262.0
# 2018-08-14   895.0   508.0   264.0  3150.0  ...   895.0   492.0   264.0
# 2018-08-15   895.0   516.0   264.0  3220.0  ...   895.0   496.0   262.0
# 2018-08-16   895.0   498.0   264.0  3180.0  ...   895.0   496.0   264.0
# ...            ...     ...     ...     ...  ...     ...     ...     ...
# 2023-08-04   615.0  1605.0  1155.0  5725.0  ...   610.0  1600.0  1155.0
# 2023-08-07   625.0  1630.0  1145.0  5725.0  ...   615.0  1605.0  1125.0
# 2023-08-08   620.0  1640.0  1165.0  5750.0  ...   620.0  1630.0  1130.0
# 2023-08-09   625.0  1620.0  1160.0  5725.0  ...   615.0  1620.0  1150.0
# 2023-08-10   635.0  1635.0  1150.0  5725.0  ...   620.0  1610.0  1120.0
#
#                                        Volume
#            BBRI.JK EMTK.JK HRUM.JK    ASSA.JK      BBRI.JK   EMTK.JK   HRUM.JK
# Date
# 2018-08-10  3350.0   895.0   534.0   617100.0  115961500.0      5000  11899000
# 2018-08-13  3300.0   895.0   538.0  1361200.0  179328600.0      5000  12749500
# 2018-08-14  3090.0   895.0   500.0   824200.0  154831700.0      5000  10271000
# 2018-08-15  3150.0   895.0   512.0  1645500.0  138367300.0      5000   9440500
# 2018-08-16  3180.0   895.0   518.0   822200.0  163665300.0      5000  14795000
# ...            ...     ...     ...        ...          ...       ...       ...
# 2023-08-04  5700.0   635.0  1640.0  6441800.0  150738500.0  17529400  19118900
# 2023-08-07  5600.0   620.0  1605.0  4244600.0   88104900.0   9565300  11626200
# 2023-08-08  5700.0   625.0  1645.0  6298500.0   89189600.0   7678900   7901500
# 2023-08-09  5650.0   615.0  1650.0  5450700.0   91930000.0  13326900   6810700
# 2023-08-10  5675.0   625.0  1625.0  5383000.0   85574500.0  17166200   9454000
#
# [1237 rows x 24 columns]

# %%
mu_bbri = pect.mean()['BBRI.JK']
sigma_bbri = pect.std()['BBRI.JK']

# %%
def stock_monte_carlo_bbri(start_price_bbri,days,mu_bbri,sigma_bbri):
    price = np.zeros(days)
    price[0] = start_price_bbri
    drift = np.zeros(days)
    shock = np.zeros(days)
    
    for x in range(1,days):
        drift[x] = mu_bbri * dt
        shock[x] = np.random.normal(loc=mu_bbri*dt, scale=sigma_bbri * np.sqrt(dt))
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    return price

# %%
start_price_bbri = 5250

for x in range(1000):
    plt.plot(stock_monte_carlo_bbri(start_price_bbri,days,mu_bbri,sigma_bbri))
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Method for BBRI')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Method for BBRI')

# %%
simulations_bbri = np.zeros(runs)

for x in range(runs):
    simulations_bbri[x] = stock_monte_carlo_bbri(start_price_bbri,days,mu_bbri,sigma_bbri)[days - 1]

# %%
q_bbri = np.percentile(simulations_bbri,1)

plt.hist(simulations_bbri,bins=100)

plt.figtext(0.6,0.8,s="Start Price: Rp.%.2f" %start_price_bbri)
plt.figtext(0.6,0.7,s="Mean Final Price: Rp.%.2f" %simulations_bbri.mean())
plt.figtext(0.6,0.6,s="VaR (0.99): Rp.%.2f" %(start_price_bbri - q_bbri))
plt.figtext(0.15,0.6,s="q(0.99): Rp.%.2f" %q_bbri)
plt.axvline(x=q_bbri,linewidth=4,color='r')
plt.title("Final price distribution for BBRI Stock after %s days" %days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for BBRI Stock after 365 days')

# %%
mu_emtk = pect.mean()['EMTK.JK']
sigma_emtk = pect.std()['EMTK.JK']

# %%
def stock_monte_carlo_emtk(start_price_emtk,days,mu_emtk,sigma_emtk):
    price = np.zeros(days)
    price[0] = start_price_emtk
    drift = np.zeros(days)
    shock = np.zeros(days)
    
    for x in range(1,days):
        drift[x] = mu_emtk * dt
        shock[x] = np.random.normal(loc=mu_emtk*dt, scale=sigma_emtk * np.sqrt(dt))
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    return price

# %%
start_price_emtk = 655

for x in range(1000):
    plt.plot(stock_monte_carlo_emtk(start_price_emtk,days,mu_emtk,sigma_emtk))
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Method for EMTK')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Method for EMTK')

# %%
simulations_emtk = np.zeros(runs)

for x in range(runs):
    simulations_emtk[x] = stock_monte_carlo_emtk(start_price_emtk,days,mu_emtk,sigma_emtk)[days - 1]

# %%
q_emtk = np.percentile(simulations_emtk,1)

plt.hist(simulations_emtk,bins=100)

plt.figtext(0.6,0.8,s="Start Price: Rp.%.2f" %start_price_emtk)
plt.figtext(0.6,0.7,s="Mean Final Price: Rp.%.2f" %simulations_emtk.mean())
plt.figtext(0.6,0.6,s="VaR (0.99): Rp.%.2f" %(start_price_emtk - q_emtk))
plt.figtext(0.15,0.6,s="q(0.99): Rp.%.2f" %q_emtk)
plt.axvline(x=q_emtk,linewidth=4,color='r')
plt.title("Final price distribution for BBRI Stock after %s days" %days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for BBRI Stock after 365 days')

# %%
df_stock.head()
# Out:
#            Adj Close                                        Close
#              ASSA.JK      BBRI.JK     EMTK.JK     HRUM.JK ASSA.JK BBRI.JK
# Date
# 2018-08-10     262.0  2809.611816  886.302429  493.545654   262.0  3390.0  \
# 2018-08-13     262.0  2602.412842  886.302429  458.685577   262.0  3140.0
# 2018-08-14     262.0  2594.125000  886.302429  466.024506   262.0  3130.0
# 2018-08-15     260.0  2660.428467  886.302429  473.363525   260.0  3210.0
# 2018-08-16     260.0  2527.821289  886.302429  456.850861   260.0  3050.0
#
#                               High          ...     Low            Open
#            EMTK.JK HRUM.JK ASSA.JK BBRI.JK  ... EMTK.JK HRUM.JK ASSA.JK
# Date                                        ...
# 2018-08-10   895.0   538.0   262.0  3470.0  ...   895.0   534.0   260.0  \
# 2018-08-13   895.0   500.0   264.0  3320.0  ...   895.0   500.0   262.0
# 2018-08-14   895.0   508.0   264.0  3150.0  ...   895.0   492.0   264.0
# 2018-08-15   895.0   516.0   264.0  3220.0  ...   895.0   496.0   262.0
# 2018-08-16   895.0   498.0   264.0  3180.0  ...   895.0   496.0   264.0
#
#                                        Volume
#            BBRI.JK EMTK.JK HRUM.JK    ASSA.JK      BBRI.JK EMTK.JK   HRUM.JK
# Date
# 2018-08-10  3350.0   895.0   534.0   617100.0  115961500.0    5000  11899000
# 2018-08-13  3300.0   895.0   538.0  1361200.0  179328600.0    5000  12749500
# 2018-08-14  3090.0   895.0   500.0   824200.0  154831700.0    5000  10271000
# 2018-08-15  3150.0   895.0   512.0  1645500.0  138367300.0    5000   9440500
# 2018-08-16  3180.0   895.0   518.0   822200.0  163665300.0    5000  14795000
#
# [5 rows x 24 columns]

# %%
df_stock[[('Close','ASSA.JK'),('Open','BBRI.JK')]]
# Out:
#              Close    Open
#            ASSA.JK BBRI.JK
# Date
# 2018-08-10   262.0  3350.0
# 2018-08-13   262.0  3300.0
# 2018-08-14   262.0  3090.0
# 2018-08-15   260.0  3150.0
# 2018-08-16   260.0  3180.0
# ...            ...     ...
# 2023-08-04  1125.0  5700.0
# 2023-08-07  1130.0  5600.0
# 2023-08-08  1145.0  5700.0
# 2023-08-09  1120.0  5650.0
# 2023-08-10  1125.0  5675.0
#
# [1237 rows x 2 columns]
